# %%
import ipywidgets as widgets
from types import SimpleNamespace
from PIL import Image
import cv2

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value=(), description='Upload')

# %%
btn_upload = SimpleNamespace(data=[r"C:\Users\Panshul\Desktop\panshul\download\CIFAR10(CV) DATASET\test\1.png"])
img = Image.open(btn_upload.data[0])
img.show()

# %%
if btn_upload.value:
    uploaded_file = list(btn_upload.value.values())[0]           # Get the uploaded file dictionary
    image_data = uploaded_file['content']                        # This is bytes
    img = Image.open(io.BytesIO(image_data))                     # Use BytesIO to open file from bytes
    img.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 if btn_upload.value:
#       2     uploaded_file = list(btn_upload.value.values())[0]           # Get the uploaded file dictionary
#       3     image_data = uploaded_file['content']                        # This is bytes
#
# AttributeError: 'types.SimpleNamespace' object has no attribute 'value'

# %%
img = PILImage.open(btn_upload.data[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 img = PILImage.open(btn_upload.data[-1])
#
# AttributeError: type object 'PILImage' has no attribute 'open'
