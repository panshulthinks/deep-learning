# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = [
    "Thor is eating pizza, Loki is eating pizza, Ironman ate pizza already",
    "Apple is announcing new iphone tomorrow",
    "Tesla is announcing new model-3 tomorrow",
    "Google is announcing new pixel-6 tomorrow",
    "Microsoft is announcing new surface tomorrow",
    "Amazon is announcing new eco-dot tomorrow",
    "I am eating biryani and you are eating grapes"
]

# %%
v = TfidfVectorizer()
transform_output = v.fit_transform(corpus)
print(v.vocabulary_)
# Out:
# {'thor': 25, 'is': 16, 'eating': 10, 'pizza': 22, 'loki': 17, 'ironman': 15, 'ate': 7, 'already': 0, 'apple': 5, 'announcing': 4, 'new': 20, 'iphone': 14, 'tomorrow': 26, 'tesla': 24, 'model': 19, 'google': 12, 'pixel': 21, 'microsoft': 18, 'surface': 23, 'amazon': 2, 'eco': 11, 'dot': 9, 'am': 1, 'biryani': 8, 'and': 3, 'you': 27, 'are': 6, 'grapes': 13}

# %%
all_feature_names = v.get_feature_names_out()

for word in all_feature_names:
    indx = v.vocabulary_.get(word)
    print(f"{word} {v.idf_[indx]}")
# Out:
# already 2.386294361119891
# am 2.386294361119891
# amazon 2.386294361119891
# and 2.386294361119891
# announcing 1.2876820724517808
# apple 2.386294361119891
# are 2.386294361119891
# ate 2.386294361119891
# biryani 2.386294361119891
# dot 2.386294361119891
# eating 1.9808292530117262
# eco 2.386294361119891
# google 2.386294361119891
# grapes 2.386294361119891
# iphone 2.386294361119891
# ironman 2.386294361119891
# is 1.1335313926245225
# loki 2.386294361119891
# microsoft 2.386294361119891
# model 2.386294361119891
# new 1.2876820724517808
# pixel 2.386294361119891
# pizza 2.386294361119891
# surface 2.386294361119891
# tesla 2.386294361119891
# thor 2.386294361119891
# tomorrow 1.2876820724517808
# you 2.386294361119891

# %%
corpus[:2]
# Out:
# ['Thor is eating pizza, Loki is eating pizza, Ironman ate pizza already',
#  'Apple is announcing new iphone tomorrow']

# %% [markdown]
# ### lets do tf-idf on a datset

# %%
import pandas as pd

# %%
df = pd.read_csv("ecommerceDataset.csv")

# %%
print(df.shape)
df.head(50000)
# Out:
# (50424, 2)
#          Household  \
# 0        Household
# 1        Household
# 2        Household
# 3        Household
# 4        Household
# ...            ...
# 49995  Electronics
# 49996  Electronics
# 49997  Electronics
# 49998  Electronics
# 49999  Electronics
#
# ...

# %%
df.shape
# Out:
# (50424, 2)

# %%
df.Household.value_counts()
# Out:
# Household
# Household                 19312
# Books                     11820
# Electronics               10621
# Clothing & Accessories     8671
# Name: count, dtype: int64

# %%
import numpy as np

# %%
import pandas as pd

data = {
    'Category': ['Household']*19312 + 
                ['Books']*11820 + 
                ['Electronics']*10621 + 
                ['Clothing & Accessories']*8671
}

df = pd.DataFrame(data)
print(df['Category'].value_counts())
# Out:
# Category
# Household                 19312
# Books                     11820
# Electronics               10621
# Clothing & Accessories     8671
# Name: count, dtype: int64

# %%
df['Feature'] = np.random.rand(len(df))
X = df[['Feature']]
y = df['Category']

# %% [markdown]
# ### lets use SMOTE to make this a balanced dataset

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

# %%
from collections import Counter
print(Counter(y_res))
# Out:
# Counter({'Household': 19312, 'Books': 19312, 'Electronics': 19312, 'Clothing & Accessories': 19312})

# %%
df['label_num'] = df.Category.map({
    'Household': 0,
    'Books': 1,
    'Electronics': 2,
    'Clothing & Accessories': 3
})

df.head(49500)
# Out:
#                      Category   Feature  label_num
# 0                   Household  0.218228          0
# 1                   Household  0.923805          0
# 2                   Household  0.697721          0
# 3                   Household  0.075566          0
# 4                   Household  0.008701          0
# ...                       ...       ...        ...
# 49495  Clothing & Accessories  0.943359          3
# 49496  Clothing & Accessories  0.604975          3
# 49497  Clothing & Accessories  0.504572          3
# 49498  Clothing & Accessories  0.754906          3
# 49499  Clothing & Accessories  0.090240          3
#
# [49500 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df.Feature,
    df.Category, 
    test_size=0.2,
    random_state=2022,
    stratify=df.Category
)

# %%
print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
# Out:
# Shape of X_train:  (40339,)
# Shape of X_test:  (10085,)

# %%
X_train.head()
# Out:
# 5025     0.249402
# 46009    0.676515
# 43491    0.110709
# 38048    0.541473
# 49708    0.847474
# Name: Feature, dtype: float64

# %%
y_train.value_counts()
# Out:
# Category
# Household                 15449
# Books                      9456
# Electronics                8497
# Clothing & Accessories     6937
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# Category
# Household                 3863
# Books                     2364
# Electronics               2124
# Clothing & Accessories    1734
# Name: count, dtype: int64

# %%
smote = SMOTE()
X_train_bal, y_train_bal = smote.fit_resample(X_train[['feature']], y_train)

X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 2
#       1 smote = SMOTE()
# ----> 2 X_train_bal, y_train_bal = smote.fit_resample(X_train[['feature']], y_train)
#       4 X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1162, in Series.__getitem__(self, key)
#    1159     key = np.asarray(key, dtype=bool)
#    1160     return self._get_rows_with_mask(key)
# -> 1162 return self._get_with(key)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1203, in Series._get_with(self, key)
#    1200         return self.iloc[key]
#    1202 # handle the dup indexing case GH#4246
# -> 1203 return self.loc[key]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
# ...
