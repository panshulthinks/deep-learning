# %%
import spacy

# %%
nlp = spacy.blank("en")

doc = nlp("Captain america ate 100$ of samosa. Then he said I can do this all day.")

for token in doc:
    print(token)
# Out:
# Captain
# america
# ate
# 100
# $
# of
# samosa
# .
# Then
# he
# said
# I
# can
# do
# this
# all
# day
# .

# %%
nlp.pipe_names
# Out:
# []

# %%
nlp = spacy.load("en_core_web_md")

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x184fc134950>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x184fc135910>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x184fc158350>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x184fc2b57d0>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x184fc2c0710>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x184fc1583c0>)]

# %%
doc = nlp("Captain america ate 100$ of samosa. Then he said I can do this all day.")

for token in doc:
    print(token, "|", token.pos_, "|", token.lemma_)
# Out:
# Captain | PROPN | Captain
# america | PROPN | america
# ate | VERB | eat
# 100 | NUM | 100
# $ | NOUN | $
# of | ADP | of
# samosa | NOUN | samosa
# . | PUNCT | .
# Then | ADV | then
# he | PRON | he
# said | VERB | say
# I | PRON | I
# can | AUX | can
# do | VERB | do
# this | PRON | this
# all | DET | all
# day | NOUN | day
# . | PUNCT | .

# %%
doc = nlp("tesla inc is going to acquire twitter for $45 billion")
for ent in doc.ents:
    print(ent.text, "|", ent.label_, "|", spacy.explain(ent.label_))
# Out:
# tesla inc | ORG | Companies, agencies, institutions, etc.
# $45 billion | MONEY | Monetary values, including unit

# %%
import IPython.display as ip_disp
import types, sys
sys.modules["IPython.core.display"] = types.SimpleNamespace(display=ip_disp.display, HTML=ip_disp.HTML)

from spacy import displacy
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Tony Stark gave 500 dollars to Peter Parker.")
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tony Stark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  gave
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500 dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Parker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</div></span>
