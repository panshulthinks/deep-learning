# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
doc = nlp("dog cat banana aksjfsa")

for token in doc:
    print(token.text, "Vector", token.has_vector, "OOV:", token.is_oov)
# Out:
# dog Vector True OOV: False
# cat Vector True OOV: False
# banana Vector True OOV: False
# aksjfsa Vector False OOV: True

# %%
base_token = nlp("bread")
base_token.vector.shape
# Out:
# (300,)

# %%
doc = nlp("bread sandwich burger car tiger human wheat panshul arora")
for token in doc:
    print(f"{token.text} <-> {base_token.text}:", token.similarity(base_token))
# Out:
# bread <-> bread: 1.0
# sandwich <-> bread: 0.6874560117721558
# burger <-> bread: 0.544037401676178
# car <-> bread: 0.16441147029399872
# tiger <-> bread: 0.14492356777191162
# human <-> bread: 0.21103660762310028
# wheat <-> bread: 0.6572456359863281
# panshul <-> bread: 0.0
# arora <-> bread: -0.08095177263021469
# C:\Users\Panshul\AppData\Local\Temp\ipykernel_33960\2512144811.py:3: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   print(f"{token.text} <-> {base_token.text}:", token.similarity(base_token))

# %%
def print_similarity(base_word, words_to_compare):
    base_token = nlp(base_word)
    doc = nlp(words_to_compare)
    for token in doc:
        print(f"{token.text} <-> {base_token.text}: ", token.similarity(base_token))

# %%
print_similarity("iphone", "apple samsung iphone dog kitten")
# Out:
# apple <-> iphone:  0.6339781284332275
# samsung <-> iphone:  0.6678677797317505
# iphone <-> iphone:  1.0
# dog <-> iphone:  0.1743103712797165
# kitten <-> iphone:  0.1468581259250641

# %%
king = nlp.vocab["king"].vector
man = nlp.vocab["man"].vector
woman = nlp.vocab["woman"].vector
queen = nlp.vocab["queen"].vector

result = king - man + woman

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_similarity([result], [queen])
# Out:
# array([[0.78808445]], dtype=float32)
