# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("The children were happily playing in the garden while their mother watched from the porch.")

for token in doc:
    print(token, "|", token.pos_, "|", spacy.explain(token.pos_), "|", token.tag_, "|", spacy.explain(token.tag_))
# Out:
# The | DET | determiner | DT | determiner
# children | NOUN | noun | NNS | noun, plural
# were | AUX | auxiliary | VBD | verb, past tense
# happily | ADV | adverb | RB | adverb
# playing | VERB | verb | VBG | verb, gerund or present participle
# in | ADP | adposition | IN | conjunction, subordinating or preposition
# the | DET | determiner | DT | determiner
# garden | NOUN | noun | NN | noun, singular or mass
# while | SCONJ | subordinating conjunction | IN | conjunction, subordinating or preposition
# their | PRON | pronoun | PRP$ | pronoun, possessive
# mother | NOUN | noun | NN | noun, singular or mass
# watched | VERB | verb | VBD | verb, past tense
# from | ADP | adposition | IN | conjunction, subordinating or preposition
# the | DET | determiner | DT | determiner
# porch | NOUN | noun | NN | noun, singular or mass
# . | PUNCT | punctuation | . | punctuation mark, sentence closer

# %%
doc = nlp("""Inflation rose again in April, 
continuing a climb that has pushed consumers to the brink 
and is threatening the economic expansion, the Bureau of 
Labor Statistics reported Wednesday.\n\nThe consumer price index, 
a broad-based measure of prices for goods and services, increased 8.3% 
from a year ago, higher than the Dow Jones estimate for an 8.1% gain. That 
represented a slight ease from Marchâ€™s peak but was still close to the
highest level since the summer of 1982.\
n\nRemoving volatile food and ene""")

# %%
numeral_tokens = []
noun_tokens = []

for token in doc:
    if token.pos_ == "NOUN":
        noun_tokens.append(token)
    elif token.pos_ == 'NUM':
        numeral_tokens.append(token)

# %%
numeral_tokens
# Out:
# [8.3, 8.1, 1982]

# %%
noun_tokens
# Out:
# [Inflation,
#  climb,
#  consumers,
#  brink,
#  expansion,
#  consumer,
#  price,
#  index,
#  measure,
#  prices,
#  goods,
#  services,
#  %,
#  year,
#  estimate,
#  %,
#  gain,
#  ease,
#  peak,
#  level,
#  summer,
#  food,
#  ene]

# %%
count = doc.count_by(spacy.attrs.POS)
count
# Out:
# {92: 23,
#  100: 9,
#  86: 4,
#  85: 11,
#  96: 9,
#  97: 9,
#  90: 12,
#  95: 2,
#  87: 3,
#  89: 4,
#  84: 6,
#  103: 2,
#  93: 3,
#  94: 1,
#  98: 1}

# %%
for k,v in count.items():
    print(doc.vocab[k].text, "|",v)
# Out:
# NOUN | 23
# VERB | 9
# ADV | 4
# ADP | 11
# PROPN | 9
# PUNCT | 9
# DET | 12
# PRON | 2
# AUX | 3
# CCONJ | 4
# ADJ | 6
# SPACE | 2
# NUM | 3
# PART | 1
# SCONJ | 1
